# %% [markdown]
# # Location-Aware Recommendation System - Data Exploration
#
# This notebook provides an interactive exploration of the location-aware recommendation system data and models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from pathlib import Path

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Load configuration
with open('configs/config.yaml', 'r') as f:
    config = yaml.safe_load(f)

print("Configuration loaded successfully!")
